# %%
import torch
import torch.nn as nn

# %%
m = nn.Conv1d(16, 33, 3, stride=2)
input = torch.randn(20, 16, 50)
output = m(input)
output
# Out:
# tensor([[[ 0.1837,  0.5188, -0.4390,  ...,  0.6588,  0.5016, -0.9117],
#          [-0.0063, -0.4531, -0.7024,  ..., -0.4973,  0.0212, -0.9814],
#          [-0.1210,  0.7085, -0.1856,  ..., -0.1690,  0.8543, -0.7157],
#          ...,
#          [-1.1603, -0.1696,  0.8934,  ...,  0.7662,  0.1438,  1.5812],
#          [-0.0298,  0.2616,  0.3439,  ..., -0.2286,  1.7999,  0.4694],
#          [-0.4263, -0.0552,  0.2767,  ...,  0.6732,  0.8019, -0.1352]],
#
#         [[ 0.4668, -0.3614,  1.5339,  ..., -0.4666,  0.4823,  0.3727],
#          [-0.1448,  0.6306, -0.5104,  ...,  0.5519, -0.3651, -0.7965],
#          [ 0.1254,  0.3454,  0.4071,  ...,  0.4015,  0.6904, -0.7386],
#          ...,
#          [-0.7019,  0.0326, -0.0363,  ...,  0.1864,  0.1502,  0.6410],
#          [-0.2175, -0.7349,  0.2431,  ..., -0.1039,  0.2786,  0.2933],
#          [ 0.3757, -0.0105, -0.2689,  ..., -0.8593,  0.5803,  0.4996]],
#
#         [[ 0.2133, -0.0218, -1.7941,  ...,  0.3284,  0.8828, -1.1313],
# ...
