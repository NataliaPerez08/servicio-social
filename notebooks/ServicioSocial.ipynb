# %% [markdown]
# # Servicio social
#
# Los que tienen nombre spectrum son los espectros de la tabla con el pigmento. Los que comienzan con A00 son de las cerámicas y estándares. Los que tienen extensión asd, son los que da el sistema, los que tienen extensión .txt son los ya procesados y los hr.txt son los procesados que ya se les ajustó la curva. Finalmente los espectros 12,13,14, 15 y 130 son cerámicas. Y los otros son los estándares 131-blanco, 132-Amarillo, 133-Rojo, 134-Azul y 135-Verde.

# %%
#print("Instalar librerias necesarias")
# !pip install torch torchvision
# !pip install spectral specdal
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 3.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# The reflectance of the surface of a material is its effectiveness in reflecting radiant energy. It is the fraction of incident electromagnetic power that is reflected at the boundary. Reflectance is a component of the response of the electronic structure of the material to the electromagnetic field of light, and is in general a function of the frequency, or wavelength, of the light, its polarization, and the angle of incidence. The dependence of reflectance on the wavelength is called a reflectance spectrum or spectral reflectance curve.

# %%
from matplotlib import pyplot as plt
import pandas as pd
# Read the csv file
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00131.asd.txt',delimiter='\t')

# Print columns
#print(data.columns)

dev_x = data['Wavelength']
dev_y = data['A00131.asd']
plt.plot(dev_x, dev_y)
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
plt.title('A00131.asd.txt-Blanco')
plt.show()

# Read the csv file
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00132.asd.txt',delimiter='\t')
dev_x = data['Wavelength']
dev_y = data['A00132.asd']
plt.plot(dev_x, dev_y)
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
plt.title('A00132.asd.txt-Amarillo')
plt.show()

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00133.asd.txt',delimiter='\t')
dev_x = data['Wavelength']
dev_y = data['A00133.asd']
plt.plot(dev_x, dev_y)
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
plt.title('A00133.asd.txt-Rojo')
plt.show()



data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00134.asd.txt',delimiter='\t')
dev_x = data['Wavelength']
dev_y = data['A00134.asd']
plt.plot(dev_x, dev_y)
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
plt.title('A00134.asd.txt-Azul')
plt.show()


data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00135.asd.txt',delimiter='\t')
dev_x = data['Wavelength']
dev_y = data['A00135.asd']
plt.plot(dev_x, dev_y)
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
plt.title('A00135.asd.txt-Verde')
plt.show()

# %% [markdown]
# Intentare identificar los colores presentes en una ceramica a partir de los estandares anteriores

# %% [markdown]
# La primera aproximación será convertir los estandares en tensores:

# %%
import torch


# Tensor estandar blanco
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00131.asd.txt',delimiter='\t')
wl_x = data['Wavelength']
rf = data['A00131.asd']
tensor_blanco = torch.tensor([wl_x,rf])

# Tensor estandar amarillo
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00132.asd.txt',delimiter='\t')
wl_x = data['Wavelength']
rf = data['A00132.asd']
tensor_amarillo = torch.tensor([wl_x,rf])

# Tensor estandar rojo
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00133.asd.txt',delimiter='\t')
wl_x = data['Wavelength']
rf = data['A00133.asd']
tensor_rojo = torch.tensor([wl_x,rf])

# Tensor estandar Azul
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00134.asd.txt',delimiter='\t')
wl_x = data['Wavelength']
rf = data['A00134.asd']
tensor_azul = torch.tensor([wl_x,rf])

# Tensor estandar Verde
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/A00135.asd.txt',delimiter='\t')
wl_x = data['Wavelength']
rf = data['A00135.asd']
tensor_verde = torch.tensor([wl_x,rf])


print("Tensor estandar amarillo: ",tensor_amarillo, ". \n Sus dimensiones son: ", tensor_amarillo.shape)
# Out:
# Tensor estandar amarillo:  tensor([[3.5000e+02, 3.5100e+02, 3.5200e+02,  ..., 2.4980e+03, 2.4990e+03,
#          2.5000e+03],
#         [3.1768e-01, 3.0822e-01, 2.8822e-01,  ..., 1.0364e+00, 1.0341e+00,
#          1.0251e+00]], dtype=torch.float64) .
#  Sus dimensiones son:  torch.Size([2, 2151])

# %% [markdown]
# Se definen las clases en las que clasificará

# %%
classes = ['blanco','amarillo','rojo','azul','verde']
tensor_classes = [tensor_blanco, tensor_amarillo, tensor_rojo, tensor_azul, tensor_verde]

# %% [markdown]
# # Graficación ceramica

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/spectrum00005.asd.txt',delimiter='\t')
data
dev_x = data['Wavelength']
dev_y = data['spectrum00005.asd']
#tensor_ceramica = torch.tensor([dev_x,dev_y])

#print("Tensor ceramica: ",tensor_ceramica, ". \n Sus dimensiones son: ", tensor_ceramica.shape)

plt.plot(dev_x, dev_y)
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
plt.title('d')#('A00012.asd.txt-Ceramica')
plt.show()

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Espectros FORS/spectrum00004.asd.txt',delimiter='\t')
data
dev_x = data['Wavelength']
print(type(dev_x))
dev_y = data['spectrum00004.asd']
plt.plot(dev_x, dev_y)
plt.ylabel('Reflectance')
plt.xlabel('Wavelength')
plt.title('d')#('A00012.asd.txt-Ceramica')
plt.show()
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Aproximaciones para crear modelos
# El modelo tendrá como entrada 2 atributos: la longitud de onda y la reflectancia.

# %%
# Standard PyTorch imports
import torch
from torch import nn

device = "cuda" if torch.cuda.is_available() else "cpu"

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits
model = NeuralNetwork().to(device)

X = torch.rand(1, 28, 28, device=device)
logits = model(X)
pred_probab = nn.Softmax(dim=1)(logits)
y_pred = pred_probab.argmax(1)
print(f"Predicted class: {y_pred}")
# Out:
# Predicted class: tensor([4])
