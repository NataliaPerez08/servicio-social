# %%
import os
from specdal import Collection, Spectrum, read
from matplotlib import pyplot as plt
import pandas as pd

datadir = "Espectros_FORS_2/Tablas 2/Tabla_Y4"
archivos = list()
specs = list()
etiquetas = ['A1','A2','A3','A4','A5',
             'B1','B2','B3','B4','B5',
             'C1','C2','C3','C4','C5',
             'D1','D2','D3','D4','D5',
             'E1','E2','E3','E4','E5',
            ]
cont=0
for f in os.listdir(datadir):
    data = pd.read_csv(datadir+"/"+f,delimiter='\t')
    #print(f)
    archivos.append(f)
    dev_x = data['Wavelength']
    title =str(f)[:-4]
    dev_y = data[title]
    print(len(dev_x))
    
    plt.plot(dev_x[:400], dev_y[:400])
    plt.ylabel('Reflectance')
    plt.xlabel('Wavelength')
    t = "Tabla Y4",etiquetas[cont],str(cont+1)
    plt.title(t)
    plt.show()
    cont+=1

    df = pd.DataFrame({'x': dev_x, 'y': dev_y})
    tmp_arr = df.to_numpy()
    specs.append(tmp_arr)
   

print(archivos)
len(specs)
print(cont)
# Out:
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# 2151
# ['spectrum00001.asd.txt', 'spectrum00002.asd.txt', 'spectrum00003.asd.txt', 'spectrum00004.asd.txt', 'spectrum00005.asd.txt', 'spectrum00006.asd.txt', 'spectrum00007.asd.txt', 'spectrum00008.asd.txt', 'spectrum00009.asd.txt', 'spectrum00010.asd.txt', 'spectrum00011.asd.txt', 'spectrum00012.asd.txt', 'spectrum00013.asd.txt', 'spectrum00014.asd.txt', 'spectrum00015.asd.txt', 'spectrum00016.asd.txt', 'spectrum00017.asd.txt', 'spectrum00018.asd.txt', 'spectrum00019.asd.txt', 'spectrum00020.asd.txt', 'spectrum00021.asd.txt', 'spectrum00022.asd.txt', 'spectrum00023.asd.txt', 'spectrum00024.asd.txt', 'spectrum00025.asd.txt']
# 25
